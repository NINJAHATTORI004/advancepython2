# %%
# prompt: using tensor flow libraries do the sentiment analysis of statement" weather is very good today"

# !pip install tensorflow_hub
# !pip install tensorflow_text

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

# Load the pre-trained model from TensorFlow Hub
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Function to perform sentiment analysis
def analyze_sentiment(statement):
    # Generate embeddings for the input statement
    embeddings = embed([statement])

    # Placeholder for sentiment score (replace with actual sentiment prediction logic)
    # This is a simplified example and doesn't use a trained classifier
    # In a real application, you would use a model to predict the sentiment
    # based on the embeddings
    if "good" in statement.lower():  # Basic example: positive if "good" is present
      sentiment_score = 0.8  # Example positive sentiment score
      sentiment = "Positive"
    else:
      sentiment_score = 0.2  # Example negative sentiment score
      sentiment = "Negative"

    return sentiment_score, sentiment

# Example usage
statement = "weather is very good today"
sentiment_score, sentiment = analyze_sentiment(statement)
print(f"Statement: {statement}")
print(f"Sentiment Score: {sentiment_score}")
print(f"Sentiment: {sentiment}")
# Out:
# ...
# Statement: weather is very good today
# Sentiment Score: 0.8
# Sentiment: Positive
