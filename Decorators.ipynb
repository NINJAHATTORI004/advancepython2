# %%
import time
def time_it(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args,**kwargs) # Positional and Keyword Arguments
        end = time.time()
        print(-.__name__ +" took " + str((end-start)*1000) + "mil sec") # returns name of the function
        return result
    return wrapper

@time_it # Tag at the beginning to measure the performance
def calc_square(numbers):
    result = []
    for number in numbers:
        result.append(number*number)
    return result

@time_it
def calc_cube(numbers):
    result = []
    for number in numbers:
        result.append(number*number*number)
    return result

array = range(1,100000)
out_square = calc_square(array)
out_cube = calc_cube(array)
# Out:
# calc_square took 26.9927978515625mil sec
# calc_cube took 26.984453201293945mil sec

# %%
import time

def calc_square(numbers):
    start = time.time()
    result = []
    for number in numbers:
        result.append(number*number)
    end = time.time()
    print("calc_square" +" took " + str((end-start)*1000) + "mil sec")
    return result

def calc_cube(numbers):
    start = time.time()
    result = []
    for number in numbers:
        result.append(number*number*number)
    end = time.time()
    print("calc_cube" +" took " + str((end-start)*1000) + "mil sec")
    return result
array = range(1,100000)
out_square = calc_square(array)
out_cube = calc_cube(array)
# Out:
# calc_square took 20.98822593688965mil sec
# calc_cube took 25.982141494750977mil sec

# %%
def mk(x):
    def mk1():
        print("Decorated")
        x()
    return mk1
def mk2():
    print("Ordinary")
p = mk(mk2)
p()
# Out:
# Decorated
# Ordinary

# %%
def mk(x):
    def mk1():
        print("Decorated")
        x()
    return mk1
def mk2():
    print("Ordinary")
p = mk(mk2)
p()
# Name of the Decorator function?????
# Out:
# Decorated
# Ordinary

# %% [markdown]
#  The ______ symbol along with the name of the decorator function can be placed above the definition of the function to be decorated works as an alternate way for decorating a function.
# a) #
#
# b) $
#
# c) @
#
# d) &

# %%
def f(x):
    def f1(a, b):
        print("hello")
        if b==0:
            print("NO")
            return
        return f(a, b)
    return f1
@f
def f(a, b):
    return a%b
f(4,0)
# Out:
# hello
# NO

# %%
def div(a,b):
    return(a/b)
div(4,2)
div(2,4)
# Out:
# 0.5

# %% [markdown]
# Suppose we want to build a logic such that doesn't matter what values we pass numerator should be bigger than the denominator
#
# def div(a,b):

# %%
def div(a,b):
    if a<b:
        a,b=b,a
    return(a/b)
div(4,2)
div(2,4)
# Out:
# 2.0

# %%
def div(a,b):
    return(a/b)
def modify(func):
    
    def inner(a,b):
        if a<b:
            a,b=b,a
        return func(a,b)
    return inner
div1=modify(div)
div1(2,4)
# Out:
# 2.0
